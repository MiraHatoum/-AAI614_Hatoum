# %% [markdown]
# <a href="https://colab.research.google.com/github/MiraHatoum/-AAI614_Hatoum/blob/main/Week3_Exercise_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing necessary libraries
import pandas as pd

# %%
# Define the data for the DataFrame
data = {
    "Province or Territory": [
        "Newfoundland", "Prince Edward Island", "Nova Scotia", "New Brunswick", "Atlantic",
        "Région Nord-Est", "Québec-Chaudière-Appalaches", "Centre-du-Québec", "Montréal-Laval",
        "Ouest du Québec", "Montérégie", "Province of Québec", "Province of Ontario",
        "Manitoba", "Province of Saskatchewan", "Province of Alberta", "British Columbia",
        "Yukon", "Northwest Territories", "Nunavut", "Territories", "CANADA"
    ],
    "Flu Tested": [
        1299, 307, 864, 4271, 6741, 3551, 5028, 5435, 16318, 4775, 3288, 38395, 23795,
        4911, 8391, 18824, 8731, 143, 435, 33, 611, 110399
    ],
    "Total Flu A Positive": [
        114, 38, 52, 758, 962, 717, 1098, 1281, 1458, 925, 495, 5975, 1478,
        681, 2089, 4745, 1840, 23, 140, 8, 171, 17941
    ],
    "Total Flu B Positive": [
        1, 0, 1, 2, 4, 3, 10, 34, 19, 9, 6, 81, 42,
        3, 3, 29, 10, 0, 0, 0, 0, 172
    ],
    "RSV Tested": [
        1299, 305, 869, 4274, 6747, 2633, 5039, 4613, 15945, 4250, 3275, 35755, 23518,
        4828, 8391, 15040, 8731, 122, 432, 33, 587, 103597
    ],
    "RSV Positive": [
        91, 5, 45, 131, 272, 32, 451, 350, 1237, 506, 240, 2816, 1123,
        101, 160, 0, 279, 2, 0, 0, 2, 4753
    ],
    "Adeno Tested": [
        1299, 48, 322, 1185, 2854, 0, 1399, 36, 9853, 0, 0, 11288, 13348,
        2254, 8391, 15040, 4342, None, 432, 33, 465, 57982
    ],
    "Adeno Positive": [
        12, 5, 0, 84, 101, 0, 60, 0, 313, 0, 0, 373, 117,
        25, 106, 184, 56, None, 12, 5, 17, 979
    ],
}

# %%
# Create the DataFrame
df = pd.DataFrame(data)

# %%
# Display the DataFrame
df
# Out:
#           Province or Territory  Flu Tested  Total Flu A Positive  \
# 0                  Newfoundland        1299                   114
# 1          Prince Edward Island         307                    38
# 2                   Nova Scotia         864                    52
# 3                 New Brunswick        4271                   758
# 4                      Atlantic        6741                   962
# 5               Région Nord-Est        3551                   717
# 6   Québec-Chaudière-Appalaches        5028                  1098
# 7              Centre-du-Québec        5435                  1281
# 8                Montréal-Laval       16318                  1458
# 9               Ouest du Québec        4775                   925
# 10                   Montérégie        3288                   495
# 11           Province of Québec       38395                  5975
# 12          Province of Ontario       23795                  1478
# ...
